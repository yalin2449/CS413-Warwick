# %% [markdown]
# <a href="https://colab.research.google.com/github/yalin2449/CS413-Warwick/blob/main/Access_my_data_file_on_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# connect to Google Drive to see own files in folder

# %%
# mount your local drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# look into 'data' folder

# %%
# !ls drive/My\ Drive/data
# Out:
# Evan.jpg  New_to_Colab.xlsx

# %% [markdown]
# set a 'data_dir' variable for the rest of the notebook programming.

# %%
data_dir='drive/My Drive/data/'
import matplotlib.pyplot as plt
im=plt.imread(data_dir+'Evan.jpg')

plt.imshow(im)
plt.show()
